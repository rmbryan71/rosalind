# %% [markdown]
# http://rosalind.info/problems/revp/
#
# Given: A DNA string of length at most 1 kbp in FASTA format.
#
# Return: The position and length of every reverse palindrome in the string having length between 4 and 12. You may return these pairs in any order.

# %%
from Bio.Seq import Seq
from Bio import SeqIO

def read_fasta(fasta_file):
    '''Read fasta file and return the list of records, consisting of
    description and sequence'''
    handle = open(fasta_file)
    records = list(SeqIO.parse(handle, "fasta"))
    handle.close()
    return [(str(rec.seq)) for rec in records]

# %%
def is_palindrome(input):
    seq = ''.join(input)
    length = len(seq)
    
    for i in range(0,length): #could stop half way
        #print(seq[i], seq[length-1-i])
        if not (seq[i] == seq[length-1-i]):
            return False
    return True

# %%
dataset = read_fasta("datasets/rosalind_revp_example.txt")
str1 = ''.join(str(dataset))
length = len(str1)
halfway = length//2

for i in range(0,halfway):
    for j in range(4,12):
        k = str1[i:i+j]
#         if is_palindrome(str1[i:i+j]):
        print(i, j, str1[i:i+j], k, is_palindrome(k))
# Out:
# 0 4 ['TC ['TC False
# 0 5 ['TCA ['TCA False
# 0 6 ['TCAA ['TCAA False
# 0 7 ['TCAAT ['TCAAT False
# 0 8 ['TCAATG ['TCAATG False
# 0 9 ['TCAATGC ['TCAATGC False
# 0 10 ['TCAATGCA ['TCAATGCA False
# 0 11 ['TCAATGCAT ['TCAATGCAT False
# 1 4 'TCA 'TCA False
# 1 5 'TCAA 'TCAA False
# 1 6 'TCAAT 'TCAAT False
# 1 7 'TCAATG 'TCAATG False
# 1 8 'TCAATGC 'TCAATGC False
# 1 9 'TCAATGCA 'TCAATGCA False
# 1 10 'TCAATGCAT 'TCAATGCAT False
# 1 11 'TCAATGCATG 'TCAATGCATG False
# 2 4 TCAA TCAA False
# 2 5 TCAAT TCAAT False
# 2 6 TCAATG TCAATG False
# 2 7 TCAATGC TCAATGC False
# 2 8 TCAATGCA TCAATGCA False
# 2 9 TCAATGCAT TCAATGCAT False
# 2 10 TCAATGCATG TCAATGCATG False
# 2 11 TCAATGCATGC TCAATGCATGC False
# 3 4 CAAT CAAT False
# 3 5 CAATG CAATG False
# 3 6 CAATGC CAATGC False
# 3 7 CAATGCA CAATGCA False
# 3 8 CAATGCAT CAATGCAT False
# 3 9 CAATGCATG CAATGCATG False
# 3 10 CAATGCATGC CAATGCATGC False
# 3 11 CAATGCATGCG CAATGCATGCG False
# 4 4 AATG AATG False
# 4 5 AATGC AATGC False
# 4 6 AATGCA AATGCA False
# 4 7 AATGCAT AATGCAT False
# 4 8 AATGCATG AATGCATG False
# 4 9 AATGCATGC AATGCATGC False
# 4 10 AATGCATGCG AATGCATGCG False
# 4 11 AATGCATGCGG AATGCATGCGG False
# 5 4 ATGC ATGC False
# 5 5 ATGCA ATGCA False
# 5 6 ATGCAT ATGCAT False
# 5 7 ATGCATG ATGCATG False
# 5 8 ATGCATGC ATGCATGC False
# 5 9 ATGCATGCG ATGCATGCG False
# 5 10 ATGCATGCGG ATGCATGCGG False
# 5 11 ATGCATGCGGG ATGCATGCGGG False
# 6 4 TGCA TGCA False
# 6 5 TGCAT TGCAT False
# 6 6 TGCATG TGCATG False
# 6 7 TGCATGC TGCATGC False
# 6 8 TGCATGCG TGCATGCG False
# 6 9 TGCATGCGG TGCATGCGG False
# 6 10 TGCATGCGGG TGCATGCGGG False
# 6 11 TGCATGCGGGT TGCATGCGGGT False
# 7 4 GCAT GCAT False
# 7 5 GCATG GCATG False
# 7 6 GCATGC GCATGC False
# 7 7 GCATGCG GCATGCG False
# 7 8 GCATGCGG GCATGCGG False
# 7 9 GCATGCGGG GCATGCGGG False
# 7 10 GCATGCGGGT GCATGCGGGT False
# 7 11 GCATGCGGGTC GCATGCGGGTC False
# 8 4 CATG CATG False
# 8 5 CATGC CATGC False
# 8 6 CATGCG CATGCG False
# 8 7 CATGCGG CATGCGG False
# 8 8 CATGCGGG CATGCGGG False
# 8 9 CATGCGGGT CATGCGGGT False
# 8 10 CATGCGGGTC CATGCGGGTC False
# 8 11 CATGCGGGTCT CATGCGGGTCT False
# 9 4 ATGC ATGC False
# 9 5 ATGCG ATGCG False
# 9 6 ATGCGG ATGCGG False
# 9 7 ATGCGGG ATGCGGG False
# 9 8 ATGCGGGT ATGCGGGT False
# 9 9 ATGCGGGTC ATGCGGGTC False
# 9 10 ATGCGGGTCT ATGCGGGTCT False
# 9 11 ATGCGGGTCTA ATGCGGGTCTA False
# 10 4 TGCG TGCG False
# 10 5 TGCGG TGCGG False
# 10 6 TGCGGG TGCGGG False
# 10 7 TGCGGGT TGCGGGT False
# 10 8 TGCGGGTC TGCGGGTC False
# 10 9 TGCGGGTCT TGCGGGTCT False
# 10 10 TGCGGGTCTA TGCGGGTCTA False
# 10 11 TGCGGGTCTAT TGCGGGTCTAT False
# 11 4 GCGG GCGG False
# 11 5 GCGGG GCGGG False
# 11 6 GCGGGT GCGGGT False
# 11 7 GCGGGTC GCGGGTC False
# 11 8 GCGGGTCT GCGGGTCT False
# 11 9 GCGGGTCTA GCGGGTCTA False
# 11 10 GCGGGTCTAT GCGGGTCTAT False
# 11 11 GCGGGTCTATA GCGGGTCTATA False
# 12 4 CGGG CGGG False
# 12 5 CGGGT CGGGT False
# 12 6 CGGGTC CGGGTC False
# 12 7 CGGGTCT CGGGTCT False
# 12 8 CGGGTCTA CGGGTCTA False
# 12 9 CGGGTCTAT CGGGTCTAT False
# 12 10 CGGGTCTATA CGGGTCTATA False
# 12 11 CGGGTCTATAT CGGGTCTATAT False
# 13 4 GGGT GGGT False
# 13 5 GGGTC GGGTC False
# 13 6 GGGTCT GGGTCT False
# 13 7 GGGTCTA GGGTCTA False
# 13 8 GGGTCTAT GGGTCTAT False
# 13 9 GGGTCTATA GGGTCTATA False
# 13 10 GGGTCTATAT GGGTCTATAT False
# 13 11 GGGTCTATATG GGGTCTATATG False
