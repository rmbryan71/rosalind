# %%
RNA_CODON_TABLE = {
    'UUU': 'F',     'CUU': 'L',     'AUU': 'I',     'GUU': 'V',
    'UUC': 'F',     'CUC': 'L',     'AUC': 'I',     'GUC': 'V',
    'UUA': 'L',     'CUA': 'L',     'AUA': 'I',     'GUA': 'V',
    'UUG': 'L',     'CUG': 'L',     'AUG': 'M',     'GUG': 'V',
    'UCU': 'S',     'CCU': 'P',     'ACU': 'T',     'GCU': 'A',
    'UCC': 'S',     'CCC': 'P',     'ACC': 'T',     'GCC': 'A',
    'UCA': 'S',     'CCA': 'P',     'ACA': 'T',     'GCA': 'A',
    'UCG': 'S',     'CCG': 'P',     'ACG': 'T',     'GCG': 'A',
    'UAU': 'Y',     'CAU': 'H',     'AAU': 'N',     'GAU': 'D',
    'UAC': 'Y',     'CAC': 'H',     'AAC': 'N',     'GAC': 'D',
    'UAA': 'Stop',  'CAA': 'Q',     'AAA': 'K',     'GAA': 'E',
    'UAG': 'Stop',  'CAG': 'Q',     'AAG': 'K',     'GAG': 'E',
    'UGU': 'C',     'CGU': 'R',     'AGU': 'S',     'GGU': 'G',
    'UGC': 'C',     'CGC': 'R',     'AGC': 'S',     'GGC': 'G',
    'UGA': 'Stop',  'CGA': 'R',     'AGA': 'R',     'GGA': 'G',
    'UGG': 'W',     'CGG': 'R',     'AGG': 'R',     'GGG': 'G'
}


def codon_frequencies():
    frequencies = {}
    for k, v in enumerate(RNA_CODON_TABLE):
        if not v in frequencies:
            frequencies[v] = 0
        frequencies[v] += 1
    return frequencies


def possible_rna_strings(input):
    f = codon_frequencies()
    n = f.get("Stop")

    for c in input:
        n *= f.get(c)

    return n

small_dataset = "MA"
#large_dataset = open('datasets/rosalind_mrna.txt').read().strip()

print (possible_rna_strings(small_dataset) % 1000000)
# Out:
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-3923b77abec0> in <module>()
#      40 #large_dataset = open('datasets/rosalind_mrna.txt').read().strip()
#      41
# ---> 42 print (possible_rna_strings(small_dataset) % 1000000)
#
# <ipython-input-11-3923b77abec0> in possible_rna_strings(input)
#      33
#      34     for c in input:
# ---> 35         n *= f.get(c)
#      36
#      37     return n
#
# TypeError: unsupported operand type(s) for *=: 'NoneType' and 'NoneType'
