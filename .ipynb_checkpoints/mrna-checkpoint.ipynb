# %% [markdown]
# http://rosalind.info/problems/mrna/

# %% [markdown]
# Given: A protein string of length at most 1000 aa.
#
# Return: The total number of different RNA strings from which the protein could have been translated, modulo 1,000,000. (Don't neglect the importance of the stop codon in protein translation.)

# %%
RNA_CODON_TABLE = {
    'UUU': 'F',     'CUU': 'L',     'AUU': 'I',     'GUU': 'V',
    'UUC': 'F',     'CUC': 'L',     'AUC': 'I',     'GUC': 'V',
    'UUA': 'L',     'CUA': 'L',     'AUA': 'I',     'GUA': 'V',
    'UUG': 'L',     'CUG': 'L',     'AUG': 'M',     'GUG': 'V',
    'UCU': 'S',     'CCU': 'P',     'ACU': 'T',     'GCU': 'A',
    'UCC': 'S',     'CCC': 'P',     'ACC': 'T',     'GCC': 'A',
    'UCA': 'S',     'CCA': 'P',     'ACA': 'T',     'GCA': 'A',
    'UCG': 'S',     'CCG': 'P',     'ACG': 'T',     'GCG': 'A',
    'UAU': 'Y',     'CAU': 'H',     'AAU': 'N',     'GAU': 'D',
    'UAC': 'Y',     'CAC': 'H',     'AAC': 'N',     'GAC': 'D',
    'UAA': 'Stop',  'CAA': 'Q',     'AAA': 'K',     'GAA': 'E',
    'UAG': 'Stop',  'CAG': 'Q',     'AAG': 'K',     'GAG': 'E',
    'UGU': 'C',     'CGU': 'R',     'AGU': 'S',     'GGU': 'G',
    'UGC': 'C',     'CGC': 'R',     'AGC': 'S',     'GGC': 'G',
    'UGA': 'Stop',  'CGA': 'R',     'AGA': 'R',     'GGA': 'G',
    'UGG': 'W',     'CGG': 'R',     'AGG': 'R',     'GGG': 'G'
}


def codon_frequencies():
    frequencies = {}
    for k, v in enumerate(RNA_CODON_TABLE):
        if not v in frequencies:
            frequencies[v] = 0
        frequencies[v] += 1
    return frequencies


def possible_rna_strings(input):
    f = codon_frequencies()
    n = f.get("Stop")

    for c in input:
        n *= f.get(c)

    return n

small_dataset = "MA"
#large_dataset = open('datasets/rosalind_mrna.txt').read().strip()

# %%
whos
# Out:
# Variable               Type        Data/Info
# --------------------------------------------
# RNA_CODON_TABLE        dict        n=64
# codon_frequencies      function    <function codon_frequencies at 0x107c951e0>
# possible_rna_strings   function    <function possible_rna_strings at 0x107c95488>
# small_dataset          str         MA
