# %%
import numpy as np
import pdb
import pandas as pd
import Bio
from Bio import SeqIO

# %%
def gc_load(i):
    n = len(i)
    m = 0
    
    for c in i:
        if c == 'G' or c == 'C':
            m += 1
    
    return 100*(float(m)/n)

# %%
def result_gc():
    max_gc = 0
    for record in SeqIO.parse('datasets/rosalind_gc.txt','fasta'):
        if gc_load(record.seq) > max_gc:
            max_gc = gc_load(record.seq)
            max_gc_record_name = record.name
    print (max_gc_record_name, max_gc)

# %%
result_gc()
# Out:
# Rosalind_2767 51.216814159292035

# %%
def result_cons():
    dataset = SeqIO.parse('datasets/rosalind_cons.txt','fasta')
    df = pd.DataFrame(index=int, columns=list('ACGT'))
    
    for record in dataset:
        for index, letter in enumerate(record.seq):
            if letter == 'A':
                df.at[index,1]+=1
            if letter == 'C':
                df.at[index,2]+=1
    
    print(profile)
                
        
result_cons()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-02ad4cfebbb4> in <module>()
#      13
#      14
# ---> 15 result_cons()
#
# <ipython-input-57-02ad4cfebbb4> in result_cons()
#       1 def result_cons():
#       2     dataset = SeqIO.parse('datasets/rosalind_cons.txt','fasta')
# ----> 3     df = pd.DataFrame(index=int, columns=list('ACGT'))
#       4
#       5     for record in dataset:
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     328                                  dtype=dtype, copy=copy)
#     329         elif isinstance(data, dict):
# --> 330             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     331         elif isinstance(data, ma.MaskedArray):
#     332             import numpy.ma.mrecords as mrecords
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     427
#     428             else:
# --> 429                 index = _ensure_index(index)
#     430
#     431             arrays = []
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in _ensure_index(index_like, copy)
#    4210             index_like = copy(index_like)
#    4211
# -> 4212     return Index(index_like)
#    4213
#    4214
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, fastpath, tupleize_cols, **kwargs)
#     372                         pass
#     373             # other iterable of some kind
# --> 374             subarr = _asarray_tuplesafe(data, dtype=object)
#     375             return Index(subarr, dtype=dtype, copy=copy, name=name, **kwargs)
#     376
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/common.py in _asarray_tuplesafe(values, dtype)
#     377
#     378     if not (isinstance(values, (list, tuple)) or hasattr(values, '__array__')):
# --> 379         values = list(values)
#     380     elif isinstance(values, Index):
#     381         return values.values
#
# TypeError: 'type' object is not iterable
