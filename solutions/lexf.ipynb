# %% [markdown]
# Given: A collection of at most 10 symbols defining an ordered alphabet, and a positive integer n (n≤10).
#
# Return: All strings of length n that can be formed from the alphabet, ordered lexicographically (use the standard order of symbols in the English alphabet).

# %%
import itertools

# def lexf(mode):
#     if mode == 'example':
#         with open('./datasets/rosalind_lexf_example.txt') as f:
#             dataset = f.read()
#     elif mode == 'rosalind':
#         with open('./datasets/rosalind_lexf.txt') as f:
#             dataset = f.read()
#     elif mode == 'beast':
#         with open('./datasets/rosalind_lexf_beast.txt') as f:
#             dataset = f.read()
#     else:
#         print('Incorrect mode value. Valid entries are: sample, rosalind, beast.')
        
def lexf():
    dataset = 'ABCDEFGHIJKLMNOP'
    
    for x in itertools.product(dataset, repeat=4):
        print(str(''.join(x)), end='\r')
   
# %timeit lexf()
# Out:
# 22.1 s ± 330 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
